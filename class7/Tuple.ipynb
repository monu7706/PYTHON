# %% [markdown]
# ## TUPLES
# ### ordered
# ### immutable, once created the tuple later can't be modified
# ### duplicates allowed

# %% [markdown]
# ## add

# %%
t1=(2,3,4,5)
t1
# Out:
# (2, 3, 4, 5)

# %%
t2=(2,3,(5,6),8)
t2
# Out:
# (2, 3, (5, 6), 8)

# %%
t3= ((2,3),(4,5),(6,8))
t3
# Out:
# ((2, 3), (4, 5), (6, 8))

# %% [markdown]
# ## 2.access

# %%
t4=(5,6,7,8,9)
t4[3]
# Out:
# 8

# %%
t4[2:5]
# Out:
# (7, 8, 9)

# %%
t4[-1]
# Out:
# 9

# %%
t4[::-1]
# Out:
# (9, 8, 7, 6, 5)

# %% [markdown]
# ## 3. edit

# %%
t4[2]=89 ## because immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 t4[2]=89
#
# TypeError: 'tuple' object does not support item assignment

# %%
l4= list(t4)
l4[2]=50
l4
tuple(l4)
# Out:
# (5, 6, 50, 8, 9)

# %%
t4
# Out:
# (5, 6, 7, 8, 9)

# %% [markdown]
# ## 4 add

# %%
t5=(5,6,7,8)
t6=(7,8,9,4)

# %%
t5+t6
# Out:
# (5, 6, 7, 8, 7, 8, 9, 4)

# %%
t5*3
# Out:
# [5, 6, 7, 8, 5, 6, 7, 8, 5, 6, 7, 8]

# %%
6 in t5
# Out:
# True

# %% [markdown]
# ## 5 . DELETE

# %%
t5.pop()
# Out:
# 7
