# %% [markdown]
# ## Dictionary
# ### mapping the key value
# ### {key:value} i.d {k1:v1,k2:v2,k3:v3}

# %%
d1= {"name":"alex","age":30,"profession":"SDE","Customer_name":"Alex"}

# %%
d1
# Out:
# {'name': 'alex', 'age': 30, 'profession': 'SDE', 'Customer_name': 'Alex'}

# %%
d2 = {"name":{"customer_name":"john","age":40,"profession":"ds",},"locality":"newyork","pincode":122001}

# %%
d2
# Out:
# {'name': {'customer_name': 'john', 'age': 40, 'profession': 'ds'},
#  'locality': 'newyork',
#  'pincode': 122001}

# %%
d1
# Out:
# {'name': 'alex', 'age': 30, 'profession': 'SDE', 'Customer_name': 'Alex'}

# %%
d1["name"]
# Out:
# 'alex'

# %%
d1["age"]
# Out:
# 30

# %%
d1.get("name")
# Out:
# 'alex'

# %%
d2["name"]["profession"]
# Out:
# 'ds'
