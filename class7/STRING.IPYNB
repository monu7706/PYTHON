# %%
S1 ="SKILLCIRCLE IS VERY SUPPORTIVE ORGANISATION".endswith("N")
S1
# Out:
# True

# %%
s2 = "world"

# %%
l1= ["p1.py","t1.txt","y1.csv","p2.py","p3.py","t2.txt","y2.csv"]
l2=[]
for i in l1:
    if i.endswith(".txt"):
        l2.append(i)
print(l2)
# Out:
# ['t1.txt', 't2.txt']

# %%
a = "the world of data is epiccentre of growth"
a.split()
# Out:
# ['the', 'world', 'of', 'data', 'is', 'epiccentre', 'of', 'growth']

# %%
a.split("is")
# Out:
# ['the world of data ', ' epiccentre of growth']

# %%
b = ['the', 'world', 'of', 'data', 'is', 'epiccentre', 'of', 'growth']
" ".join(b)
# Out:
# 'the world of data is epiccentre of growth'

# %%
c = ['the world of data ', ' epiccentre of growth']
"is".join(c)
# Out:
# 'the world of data is epiccentre of growth'

# %%
d = "the world of data is epiccentre of growth"
d.replace("growth","progress")
# Out:
# 'the world of data is epiccentre of progress'

# %%
e = "    hello world   "
print(e.lstrip())
print(e.rstrip())
print(e.strip())
# Out:
# hello world
#     hello world
# hello world
