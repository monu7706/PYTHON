# %% [markdown]
# ## python datatype

# %%
# for heading click markdown and type ##python datatype 
# new line me output print karwane ke liye \n and 
### 1.primitive datatypes
### 1.1 INT i.e 1,-1,576,-43
### 1.2 FLOAT i.e 2.3, 4.6
### 1.3 COMPLEX i.e 2+3j, -5+8j
### 1.4 BOOL i.e True, False
### 1.5 STR i.e "johnson", "john smith"

# %% [markdown]
# ### 1.1 INT i.e 1, -1, 567, -43

# %%
print(57)
# Out:
# 57

# %%
print(-1)
# Out:
# -1

# %%
print(-1)
# Out:
# -1

# %%
print(567)
# Out:
# 567

# %%
print(576)
# Out:
# 576

# %% [markdown]
# ####1.2 FLOAT i.e 2.3, 4.6

# %%
print(2.3)
# Out:
# 2.3

# %%
print(4.6)
# Out:
# 4.6

# %% [markdown]
# ####1.3 COMPLEX i.e 2+3j, -5+8j

# %%
j=5
print(2+3*j)
# Out:
# 17

# %%
print(-5+8*j)
# Out:
# 35

# %% [markdown]
# #### 1.4 BOOL i.e True, False

# %%
print(True)
print(False)
# Out:
# True
# False

# %%
a=True
b=False
print(a)
print(b)
# Out:
# True
# False

# %% [markdown]
# #### 1.5 STR i.e "johnson", "john smith"

# %%
print("johnson","johnsmith")
print("johnson")
print("johnsmith")
# Out:
# johnson johnsmith
# johnson
# johnsmith

# %%
a= "johnson" 
b = "johnsmith"
print(a,b)
print(a)
print(b)
# Out:
# johnson johnsmith
# johnson
# johnsmith

# %% [markdown]
# ### 2.Sequence Datatype
# #### 2.1 LIST

# %%
l1=[34,"apple",3.4]
print(type(l1))
print(l1)
# Out:
# <class 'list'>
# [34, 'apple', 3.4]

# %%
print(l1)
print(l1[0])
print(l1[1])
print(l1[2])
print(l1[-1])
print(l1[-2])
print(l1[-3])
# Out:
# [34, 'apple', 3.4]
# 34
# apple
# 3.4
# 3.4
# apple
# 34

# %% [markdown]
# ### 2.2 Tuple

# %%
t1=(3,4,6,"A") 
print(t1)
print(t1[-2])
# Out:
# (3, 4, 6, 'A')
# 6

# %%
print(t1)
print(t1[0])
print(t1[1])
print(t1[2])
print(t1[3])
print(t1[-1])
print(t1[-2])
print(t1[-3])
print(t1[-4])
# Out:
# (3, 4, 6, 'A')
# 3
# 4
# 6
# A
# A
# 6
# 4
# 3

# %% [markdown]
# ### 2.3 range

# %%
range(0,10)
# Out:
# range(0, 10)

# %% [markdown]
# ### 3. set types

# %%
s1={3,4,5,6,6,7,7,7,7,7}
print(s1)
# Out:
# {3, 4, 5, 6, 7}

# %% [markdown]
# ### MAPPING DATATYPE

# %%
dict= {"name":"amit","age":30,"profession":"sde"}
print(dict)
# Out:
# {'name': 'amit', 'age': 30, 'profession': 'sde'}

# %% [markdown]
# 5#### user defined datatype

# %%
class car:
    pass
