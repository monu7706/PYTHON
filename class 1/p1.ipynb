# %% [markdown]
# ## python print statement

# %%
x=5
print(x)
print("adarsh")
print("hello world")
# Out:
# 5
# adarsh
# hello world

# %%
print(45)
# Out:
# 45

# %%
y=10
print(y)
# Out:
# 10

# %%
x=30
print(x)
# Out:
# 30

# %%
print(x+y)
# Out:
# 40

# %%
print('abc')
# Out:
# abc

# %%
print('''abc''')
# Out:
# abc

# %%
print("""adarsh""")
# Out:
# adarsh

# %%
print("abc",45,"ADARSH")
# Out:
# abc 45 ADARSH

# %%
print("I am adarsh \ni have a special characteristics \nthat should not be revealed")
# Out:
# I am adarsh
# i have a special characteristics
# that should not be revealed

# %%
x1="johnson"
x2=56
x3="john smith"
print(x1, x2, x3,)
# Out:
# johnson 56 john smith

# %%
print(f"my name is {x1},and i am {x2} year old, my friend name is {x3}")
# Out:
# my name is johnson,and i am 56 year old, my friend name is john smith

# %%
print("my name is",x1,"my age is",x2,"year old","my friend name is",x3)
# Out:
# my name is johnson my age is 56 year old my friend name is john smith

# %%
print("xyz","abc","uvw")
print("xyz","abc","uvw" ,sep=",")
print("xyz","abc","uvw" ,end=",")
# Out:
# xyz abc uvw
# xyz,abc,uvw
# xyz abc uvw,

# %%
a1="hello"
a2="world"

# %%
print(a1)
print(a2)
print(a1,a2)
# Out:
# hello
# world
# hello world

# %%
print(a1,end=" ")
print(a2)
# Out:
# hello world
