# %%
## NUMPY PRACTICE PROBLEM
## Take 5 input array where each array will be considered as a column
## so this way you have total 5 arrays .
## deliberately you have to take all columns (array) of different data 
## types (int, float, boolean,string, date).then you have to go for all the data 
## cleaning/engineering part where , first target is to convert all into proper numeric 
## (int/float). then have to make table , i mean stack all columns so that 
## a 2d table could be formed. your previous practice of stacking and datatype
## conversion, and array creation etc. logic would be practices from
## this problem?

# %%
import numpy as np

# %%
a=a.astype('float') ## isse data type change kr sakte hai

# %%
x=np.array(['a','b','c','d'])

# %%
m, n = np.unique(x, return_index = True)

# %%
m
# Out:
# array(['a', 'b', 'c', 'd'], dtype='<U1')

# %%
n
# Out:
# array([0, 1, 2, 3])

# %%
from datetime import datetime

# %%
arr1 = ([2,4,6,6,4,7])
# Out:
# [2, 4, 6, 6, 4, 7]

# %%
arr2=np.array([1.2, 4.2, 7.3, 2.5])
arr2.dtype
# Out:
# dtype('float64')

# %%
arr3=np.array([True,False,True])
arr3.dtype
# Out:
# dtype('bool')

# %%
arr4= np.array(["a","b","c","d"])
arr4.dtype
# Out:
# dtype('<U1')

# %%
m,n = np.unique(arr4,return_index = True)
# Out:
# array(['a', 'b', 'c', 'd'], dtype='<U1')

# %%
m.dtype
# Out:
# dtype('<U1')

# %%
n
n.dtype
# Out:
# dtype('int64')

# %%
from datetime import date

# %%
arr5 = np.array([np.datetime64(date(2020,6,4)),np.datetime64(date(2019,12,11))])

# %%
arr5.dtype
# Out:
# dtype('<M8[D]')
