# %% [markdown]
# #### 1.ARITHMETIC OPERATOR

# %% [markdown]
# ## ADDITION

# %%
## ADDITION 
a=10
b=20
a+b
# Out:
# 30

# %%
## subtraction
a-b
# Out:
# -10

# %%
## multiplication
a*b
# Out:
# 200

# %%
## division
a/b
# Out:
# 0.5

# %%
## power / enponential
a**b
# Out:
# 100000000000000000000

# %%
## floor division
a//b
# Out:
# 0

# %%
a=50
a
# Out:
# 50

# %%
a=45

# %%
## modulus
a%b
# Out:
# 10

# %% [markdown]
# #### 2.ASSIGNMENT OPERATOR

# %%
y=45

# %%
z=y+10

# %%
y+=10

# %% [markdown]
# #### 3 COMPARSION OPERATOR

# %%
x=10
y=30
x==y
# Out:
# False

# %%
x>y
# Out:
# False

# %%
x<y
# Out:
# True

# %%
x<=y
# Out:
# True

# %%
x>=y
# Out:
# False

# %%
x!=y
# Out:
# True

# %% [markdown]
# #### 4 LOGICAL OPERATOR

# %%
z=70
h=50

# %%
z>20 and h<20
# Out:
# False

# %%
z>20 or h<20
# Out:
# True

# %%
not(z>50)
# Out:
# False

# %% [markdown]
# #### 5 BITWISE OPERATOR

# %%
## 0->0000,
## 1->0001,
## 2->0012,
## 3->0011,
## 4->0100,
## 5->0101,
## 6->0110, machine language binary 0,1 me hi hota hai

# %%
##  And operator
a=1
b=1
print(a&b)
# Out:
# 1

# %%
x=2 ,##0010
y = 3,## 0011
print(x and y)##0010
# Out:
# (3,)

# %%
## OR operator
j=2 ## 0010
k=4 ## 0100
print(j|k) ## 0110
# Out:
# 2

# %%
## Not operator
r=3
print(~r)
# Out:
# -4

# %%
## XOR Operator
message=5
security_key = 3
# ENCRYPTION 
encrypted = message ^ security_key
print("Encrypted:",encrypted)
#Decryption(apply XOR again with same key)
decrypted = encrypted ^ security_key
print("Decrypted:", decrypted)
# Out:
# Encrypted: 6
# Decrypted: 5

# %%
## right and left shift operator
m = 3 ## 000_0011_0000
print(m>>1)
print(m<<1)
# Out:
# 1
# 6

# %% [markdown]
# #### 6. MEMBERSHIP OPERATOR

# %%
city = "gurgaaon"
print("o" in city)
print("o" not in city)
# Out:
# True
# False

# %% [markdown]
# #### 7. IDENTITY OPERATOR

# %%
x = 5
y = 5
print(id(x))
print(id(y))
print(x is y)
print(x is not y)
# Out:
# 140710007239720
# 140710007239720
# True
# False

# %%
a = [1,2,3]
b = [1,2,3]
print(a is b)
print(a is not b)
# Out:
# False
# True

# %% [markdown]
# #### Problem 1
# ## take user input of 3 digit number then find out three following
# ## 1.Unit digit
# ## 2. Tens digit
# ## 3. Hundreds digit

# %%
### 345 => unit digit=5, tens digit=4, hunderd digit=3,    o/p->5+4+3=12

# %%
a = int(input("Enter Unit digit 5: "))
b = int(input("Enter Tens digit 4: "))
c =  int(input("Enter Hundreds digit 3: "))
print("Total: ", a,"+",b,"+",c,"=", a+b+c)
# Out:
# Total:  5 + 4 + 3 = 12

# %%
a = int(input("Enter first digit: "))
print(a)
num1=a%10
print(num1)
a=a//10
num2=a%10
print(num2)
a=a//10
num3=a%10
print(num3)
print(num1+num2+num3)
# Out:
# 234
# 4
# 3
# 2
# 9

# %%
hr@educorex.in
gravit.srivastava@avaipl.com
subject ->application-data analyst
role ->data analyst

--sql,excel,python, statistics, powerbi

# %%
data['RANK'].DUPLIOCATED()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 data['Average gross'][5]
#
# NameError: name 'data' is not defined
