# %% [markdown]
#  ### slicing

# %%
a=5
print(a)
# Out:
# 5

# %%
elements = [50,70,30,20,90,10,50]
elements_slice = elements[1:3]
print(elements_slice)
# Out:
# [70, 30]

# %%
elements = [50,70,30,20,90,10,50]
print(elements[1:3])
# Out:
# [70, 30]

# %%
print(elements[::2])
# Out:
# [50, 30, 90, 50]

# %%
nested_element=[0,1],[2,3]
print(nested_element)
# Out:
# ([0, 1], [2, 3])

# %%
my_list.method()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 my_list.method()
#
# NameError: name 'my_list' is not defined

# %%
fruits=["apple", "banana","orange"]
fruits.append("grapes")
print(fruits)
# Out:
# ['apple', 'banana', 'orange', 'grapes']

# %%
list1=[1,2,3]
list2=[4,5,6]
list1.append(list2)
print(list1)
# Out:
# [1, 2, 3, [4, 5, 6]]

# %%
print(list2)
list2.insert(1,9)
print(list2)
# Out:
# [4, 9, 9, 5, 6]
# [4, 9, 9, 9, 5, 6]

# %%
# print(fruits)
# fruits.pop(2)
print(fruits)
# Out:
# ['apple', 'banana', 'grapes']

# %%
fruits.clear()
print(fruits)
# Out:
# []

# %%
github se data lene ke liye in terminal type git clone paste FileLink
