# %% [markdown]
# ### take user input of any n digit number then do sum of each indivisual digits and give in output.
# ## i.e . n=

# %%
num = int(input("Enter number"))
print("digits are: ")
i = 0
while num > 0:
   digit = num %10
   print(digit)
   i += digit
   num = num // 10
print("sum of digits : ", i)
# Out:
# digits are:
# 7
# 6
# 5
# 5
# 4
# sum of digits :  27

# %%
i = 0
while i<=5:
    print(i)
    i = i+1
    if i ==3:
        break
# Out:
# 0
# 1
# 2

# %%
i= 0
while i <=5:
    if i==3:
        break
    print(i)
    i=i+1
# Out:
# 0
# 1
# 2

# %%
num = 0
total_sum = 0
count= 0
while num>=0:
    total_sum = num
    count+=1
    num =int(input("Enter number"))
    print(num)
    if num ==0:
        print("no number entered")
        break
print("total sum",total_sum)
print("total count", count)
avg=total_sum/count
print("average is: ",avg)
# Out:
# 23450
# 2
# 4
# 0
# no number entered
# total sum 4
# total count 4
# average is:  1.0

# %%
i = 0
while i<=5:
    i+=1
    if i==3:
        continue
    print(i)
# Out:
# 1
# 2
# 4
# 5
# 6

# %% [markdown]
# ## "jackpot guessing game"

# %% [markdown]
# ### write a python program that simulates random number between 1 to 100
# ### user has to guess the number :
# ### after each guess if->
# ### 1.if guess is less than the jackpot then display "guesses one is higher"
# ### 2. if guess is higher than the jackpot then display "guessed one is lesswer"
# ### continue guessing then number until the guess number matches to jackpot number
# ### when correctly guess then print "correct match and you won 10 lakhs rupees"

# %%
import random
x = random.randint(0,100)
print(x)
# Out:
# 26

# %%
import random
jackpot = random.randint(0,100)
print(jackpot)
user_input = int(input("guess the number: "))
count = 0
while user_input!=jackpot:
    if user_input< jackpot:
        print("guess higher")
    else:
        print("guess lower")
    user_input = int(input("guess the number: "))
    count+=1
print("you guessed in",count,"chances")
print("you won the reward")
# Out:
# guess lower
# guess lower
# guess lower
# guess lower
# guess lower
# guess lower

# %%
import random
x=random.randint(0,100)
while num!=x:
    num=int(input("Guess the number"))
    if num==x:
        print ("you won 10 lack rupees")
    if num>x:
        print("Plese guess lesser")
    else:
        print("Please guess Higher")
